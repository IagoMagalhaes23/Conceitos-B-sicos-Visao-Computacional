# %% [markdown]
# <a href="https://colab.research.google.com/github/IagoMagalhaes23/Visao-Computacional/blob/main/Vis%C3%A3o_Computacional.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Notebook desenvolvido para estudos na área de Visão Computacional com Python e OpenCV

# %% [markdown]
# ##Importando bibliotecas

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ##Acessando imagens no Google Drive

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# ##Lendo uma imagem

# %%
imgColorida = cv2.imread('/content/gdrive/MyDrive/IMG_0074 (1).jpg')

# %% [markdown]
# ##Exibindo uma imagem

# %%
plt.subplot(1,1,1)
plt.axis('off')
plt.imshow(imgColorida)
plt.title('Imagem lida', fontSize=24)
plt.show()

# %% [markdown]
# ##Convertendo para tons de cinza

# %%
imgGray = cv2.cvtColor(imgColorida, cv2.COLOR_BGR2GRAY)

plt.subplot(1,1,1)
plt.axis('off')
plt.imshow(imgColorida)
plt.title('Imagem em tons de cinza', fontSize=24)
# Out:
# Text(0.5, 1.0, 'Imagem em tons de cinza')

# %% [markdown]
# ##Sistema de coordenadase manipulação de pixels

# %%
(b, g, r) = imgColorida[0, 0] #veja que a ordem BGR e não RGB

# %%
print('O pixel (0, 0) tem as seguintes cores:')
print('Vermelho:', r, 'Verde:', g, 'Azul:', b)
# Out:
# O pixel (0, 0) tem as seguintes cores:
# Vermelho: 1 Verde: 31 Azul: 65

# %% [markdown]
# ##Plotando grade de quadrados amarelos

# %%
for y in range(0, imgColorida.shape[0], 20): #percorre linhas
  for x in range(0, imgColorida.shape[1], 20): #percorre colunas
    imgColorida[y:y+15, x: x+15] = (0,255,255)

# %%
plt.subplot(1,1,1)
plt.axis('off')
plt.imshow(imgColorida)
plt.title('Imagem com grade de quadrados amarelos', fontSize=24)
# Out:
# Text(0.5, 1.0, 'Imagem com grade de quadrados amarelos')

# %% [markdown]
# ##Fatiamento e desenho sobre a imagem

# %% [markdown]
# ###Lendo uma imagem e cria vários retângulos coloridos sobre ela

# %%
#Cria um retangulo azul por toda a largura da imagem
imgColorida[30:50, :] = (255, 0, 0)
#Cria um quadrado vermelho
imgColorida[100:150, 50:100] = (0, 0, 255)
#Cria um retangulo amarelo por toda a altura da imagem
imgColorida[:, 200:220] = (0, 255, 255)
#Cria um retangulo verde da linha 150 a 300 nas colunas 250 a 350
imgColorida[150:300, 250:350] = (0, 255, 0)
#Cria um quadrado ciano da linha 150 a 300 nas colunas 250 a 350
imgColorida[300:400, 50:150] = (255, 255, 0)
#Cria um quadrado branco
imgColorida[250:350, 300:400] = (255, 255, 255)
#Cria um quadrado preto
imgColorida[70:100, 300: 450] = (0, 0, 0)

# %%
plt.subplot(1,1,1)
plt.axis('off')
plt.imshow(imgColorida)
plt.title('Imagem com quadrados coloridos', fontSize=24)
# Out:
# Text(0.5, 1.0, 'Imagem com quadrados coloridos')

# %% [markdown]
# ###Desenhando formas geométricas na imagem

# %%
imagem = cv2.imread('/content/gdrive/MyDrive/IMG_0074 (1).jpg')
vermelho = (0, 0, 255)
verde = (0, 255, 0)
azul = (255, 0, 0)
cv2.line(imagem, (0, 0), (500, 500), verde)
cv2.line(imagem, (300, 200), (150, 150), vermelho, 10)
cv2.rectangle(imagem, (20, 20), (120, 120), azul, 10)
cv2.rectangle(imagem, (200, 50), (225, 125), verde, -1)
(X, Y) = (imagem.shape[1] // 2, imagem.shape[0] // 2)
for raio in range(1000, 1575, 15):
  cv2.circle(imagem, (X, Y), raio, vermelho)

# %%
plt.subplot(1,1,1)
plt.axis('off')
plt.imshow(imagem)
plt.title('Imagem com formas geométricas', fontSize=24)
# Out:
# Text(0.5, 1.0, 'Imagem com formas geométricas')

# %% [markdown]
# ##Escrevendo sobre a imagem

# %%
imagemTexto = cv2.imread('/content/gdrive/MyDrive/IMG_0074 (1).jpg')
fonte = cv2.FONT_HERSHEY_SIMPLEX
cv2.putText(imagemTexto,'OpenCV',(155,395), fonte, 20,(255,255,0),20,cv2.LINE_AA)
# Out:
# array([[[65, 31,  1],
#         [71, 35,  0],
#         [67, 32,  0],
#         ...,
#         [37, 18,  5],
#         [34, 16,  5],
#         [33, 17,  5]],
#
#        [[67, 35,  0],
#         [70, 33,  0],
#         [64, 30,  1],
#         ...,
#         [39, 20,  7],
#         [34, 17,  4],
#         [34, 16,  5]],
#
#        [[62, 30,  1],
#         [68, 33,  0],
#         [63, 29,  0],
#         ...,
#         [46, 27, 14],
#         [46, 27, 14],
#         [38, 19,  6]],
#
#        ...,
#
#        [[ 5,  0,  1],
#         [ 4,  0,  0],
#         [ 2,  0,  0],
#         ...,
#         [15,  6,  3],
#         [14,  7,  4],
#         [13,  6,  3]],
#
#        [[ 2,  0,  0],
#         [ 2,  0,  0],
#         [ 4,  0,  0],
#         ...,
#         [17,  8,  5],
#         [16,  9,  6],
#         [14,  7,  4]],
#
#        [[ 2,  0,  0],
#         [ 2,  0,  0],
#         [ 5,  0,  1],
#         ...,
#         [19, 10,  7],
#         [15,  6,  3],
#         [18,  9,  6]]], dtype=uint8)

# %%
plt.subplot(1,1,1)
plt.axis('off')
plt.imshow(imagemTexto)
plt.title('Imagem com texto', fontSize=24)
# Out:
# Text(0.5, 1.0, 'Imagem com texto')

# %% [markdown]
# ##Transformações e máscaras

# %% [markdown]
# ###Cortando uma imagem / Crop

# %%
imagemRecortada = cv2.imread('/content/gdrive/MyDrive/IMG_0074 (1).jpg')
recorte = imagemRecortada[100:200, 100:200]

# %%
plt.subplot(1,1,1)
plt.axis('off')
plt.imshow(recorte)
plt.title('Imagem recortada', fontSize=24)
# Out:
# Text(0.5, 1.0, 'Imagem recortada')

# %% [markdown]
# ###Redimensionamento / Resize

# %%
img = cv2.imread('/content/gdrive/MyDrive/IMG_0074 (1).jpg')
largura = img.shape[1]
altura = img.shape[0]
proporcao = float(altura/largura)
largura_nova = 320 #em pixels
altura_nova = int(largura_nova*proporcao)
tamanho_novo = (largura_nova, altura_nova)
img_redimensionada = cv2.resize(img, tamanho_novo, interpolation = cv2.INTER_AREA)

# %%
plt.subplot(1,1,1)
plt.axis('off')
plt.imshow(img)
plt.title('Imagem redimensionada', fontSize=24)
# Out:
# Text(0.5, 1.0, 'Imagem redimensionada')

# %% [markdown]
# ###Espelhando uma imagem / Flip

# %%
img = cv2.imread('/content/gdrive/MyDrive/IMG_0074 (1).jpg')
flip_horizontal = img[::-1,:] #comando equivalente abaixo
#flip_horizontal = cv2.flip(img, 1)

# %%
plt.subplot(1,1,1)
plt.axis('off')
plt.imshow(img)
plt.title('Original', fontSize=24)
# Out:
# Text(0.5, 1.0, 'Original')

# %%
flip_vertical = img[:,::-1] #comando equivalente abaixo
#flip_vertical = cv2.flip(img, 0)

# %%
plt.subplot(1,1,1)
plt.axis('off')
plt.imshow(flip_horizontal)
plt.title('Flip Horizontal', fontSize=24)
# Out:
# Text(0.5, 1.0, 'Flip Horizontal')

# %%
flip_hv = img[::-1,::-1] #comando equivalente abaixo
#flip_hv = cv2.flip(img, -1)

# %%
plt.subplot(1,1,1)
plt.axis('off')
plt.imshow(flip_vertical)
plt.title('Flip Vertical', fontSize=24)
# Out:
# Text(0.5, 1.0, 'Flip Vertical')

# %% [markdown]
# ###Rotacionando uma imagem / Rotate

# %%
img = cv2.imread('/content/gdrive/MyDrive/IMG_0074 (1).jpg')
(alt, lar) = img.shape[:2] #captura altura e largura
centro = (lar // 2, alt // 2) #acha o centro

M = cv2.getRotationMatrix2D(centro, 30, 1.0) #30 graus
img_rotacionada = cv2.warpAffine(img, M, (lar, alt))

# %%
plt.subplot(1,1,1)
plt.axis('off')
plt.imshow(img_rotacionada)
plt.title('Imagem rotacionada em 45 graus', fontSize=24)
# Out:
# Text(0.5, 1.0, 'Imagem rotacionada em 45 graus')

# %% [markdown]
# ###Máscaras

# %%
img = cv2.imread('/content/gdrive/MyDrive/IMG_0074 (1).jpg')
mascara = np.zeros(img.shape[:2], dtype = "uint8")
(cX, cY) = (img.shape[1] // 2, img.shape[0] // 2)
cv2.circle(mascara, (cX, cY), 100, 255, -1)
img_com_mascara = cv2.bitwise_and(img, img, mask = mascara)

# %%
plt.subplot(1,1,1)
plt.axis('off')
plt.imshow(img_com_mascara)
plt.title('Máscara aplicada à imagem', fontSize=24)
# Out:
# Text(0.5, 1.0, 'Máscara aplicada à imagem')

# %% [markdown]
# ##Sistemas de cores

# %%
img = cv2.imread('/content/gdrive/MyDrive/IMG_0074 (1).jpg')
plt.subplot(1,1,1)
plt.axis('off')
plt.imshow(img)
plt.title('Original', fontSize=24)
# Out:
# Text(0.5, 1.0, 'Original')

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
plt.subplot(1,1,1)
plt.axis('off')
plt.imshow(gray)
plt.title('Gray', fontSize=24)
# Out:
# Text(0.5, 1.0, 'Gray')

# %%
hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
plt.subplot(1,1,1)
plt.axis('off')
plt.imshow(hsv)
plt.title('HSV', fontSize=24)
# Out:
# Text(0.5, 1.0, 'HSV')

# %%
lab = cv2.cvtColor(img, cv2.COLOR_BGR2LAB)
plt.subplot(1,1,1)
plt.axis('off')
plt.imshow(lab)
plt.title('L*a*b*', fontSize=24)
# Out:
# Text(0.5, 1.0, 'L*a*b*')

# %% [markdown]
# ##Canais da imagem colorida

# %%
img = cv2.imread('/content/gdrive/MyDrive/IMG_0074 (1).jpg')
(canalAzul, canalVerde, canalVermelho) = cv2.split(img)

# %%
plt.subplot(1,1,1)
plt.axis('off')
plt.imshow(canalVermelho)
plt.title('Vermelho', fontSize=24)
# Out:
# Text(0.5, 1.0, 'Vermelho')

# %%
plt.subplot(1,1,1)
plt.axis('off')
plt.imshow(canalVerde)
plt.title('Verde', fontSize=24)
# Out:
# Text(0.5, 1.0, 'Verde')

# %%
plt.subplot(1,1,1)
plt.axis('off')
plt.imshow(canalAzul)
plt.title('Azul', fontSize=24)
# Out:
# Text(0.5, 1.0, 'Azul')

# %% [markdown]
# ####Também é possível alterar individualmente as Numpy Arrays que formam cada canal e depois juntá-las para criar novamente a imagem. Para isso use o comando:

# %%
resultado = cv2.merge([canalAzul, canalVerde, canalVermelho])

plt.subplot(1,1,1)
plt.axis('off')
plt.imshow(resultado)
plt.title('Juntando todos os canais novamente', fontSize=24)
# Out:
# Text(0.5, 1.0, 'Juntando todos os canais novamente')

# %% [markdown]
# ####Também é possível exibir os canais nas cores originais conforme abaixo:

# %%
img = cv2.imread('/content/gdrive/MyDrive/IMG_0074 (1).jpg')
(canalAzul, canalVerde, canalVermelho) = cv2.split(img)
zeros = np.zeros(img.shape[:2], dtype = "uint8")

plt.subplot(1,1,1)
plt.axis('off')
plt.imshow(cv2.merge([zeros, zeros, canalVermelho]))
plt.title('Vermelho', fontSize=24)
# Out:
# Text(0.5, 1.0, 'Vermelho')

# %%
plt.subplot(1,1,1)
plt.axis('off')
plt.imshow(cv2.merge([zeros, canalVerde, zeros]))
plt.title('Verde', fontSize=24)
# Out:
# Text(0.5, 1.0, 'Verde')

# %%
plt.subplot(1,1,1)
plt.axis('off')
plt.imshow(cv2.merge([canalAzul, zeros, zeros]))
plt.title('Azul', fontSize=24)
# Out:
# Text(0.5, 1.0, 'Azul')

# %%
plt.subplot(1,1,1)
plt.axis('off')
plt.imshow(img)
plt.title('Original', fontSize=24)
# Out:
# Text(0.5, 1.0, 'Original')

# %% [markdown]
# ##Histogramas e equalização de imagem

# %%
from matplotlib import pyplot as plt

img = cv2.imread('/content/gdrive/MyDrive/IMG_0074 (1).jpg')
img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY) #converte P&B
cv2.imshow("Imagem P&B", img) #Função calcHist para calcular o hisograma da imagem
h = cv2.calcHist([img], [0], None, [256], [0, 256])

plt.figure()
plt.title("Histograma P&B")
plt.xlabel("Intensidade")
plt.ylabel("Qtde de Pixels")
plt.plot(h)
plt.xlim([0, 256])
plt.show()

# %%
from matplotlib import pyplot as plt
img = cv2.imread('/content/gdrive/MyDrive/IMG_0074 (1).jpg')

plt.subplot(1,1,1)
plt.axis('off')
plt.imshow(img)
plt.title('Imagem colorida', fontSize=24)

#Separa os canais
canais = cv2.split(img)
cores = ("b", "g", "r")
plt.figure()
plt.title("'Histograma Colorido")
plt.xlabel("Intensidade")
plt.ylabel("Número de Pixels")
for (canal, cor) in zip(canais, cores):
  #Este loop executa 3 vezes, uma para cada canal
  hist = cv2.calcHist([canal], [0], None, [256], [0, 256])
  plt.plot(hist)
  plt.xlim([0, 256])
plt.show()

# %% [markdown]
# ###Equalização de Histograma

# %%
from matplotlib import pyplot as plt
img = cv2.imread('/content/gdrive/MyDrive/IMG_0074 (1).jpg')
img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
h_eq = cv2.equalizeHist(img)
plt.figure()
plt.title("Histograma Equalizado")
plt.xlabel("Intensidade")
plt.ylabel("Qtde de Pixels")
plt.hist(h_eq.ravel(), 256, [0,256])
plt.xlim([0, 256])
plt.show()
plt.figure()
plt.title("Histograma Original")
plt.xlabel("Intensidade")
plt.ylabel("Qtde de Pixels")
plt.hist(img.ravel(), 256, [0,256])
plt.xlim([0, 256])
plt.show()

# %% [markdown]
# ##Suavização de imagens

# %% [markdown]
# ###Suavização por cálculo da média

# %%
img = cv2.imread('/content/gdrive/MyDrive/IMG_0074 (1).jpg')
img = img[::2,::2] # Diminui a imagem
suave = np.vstack([ 
  np.hstack([img, cv2.blur(img, ( 3, 3))]),
  np.hstack([cv2.blur(img, (5,5)),cv2.blur(img, ( 7, 7))]),
  np.hstack([cv2.blur(img, (9,9)), cv2.blur(img, (11, 11))]),
])

plt.subplot(1,1,1)
plt.axis('off')
plt.imshow(suave)
plt.title('Imagem suavisadas (Blur)', fontSize=24)
# Out:
# Text(0.5, 1.0, 'Imagem suavisadas (Blur)')

# %% [markdown]
# ###Suavização pela Gaussiana

# %%
img = cv2.imread('/content/gdrive/MyDrive/IMG_0074 (1).jpg')
img = img[::2,::2] # Diminui a imagem
suave = np.vstack([
  np.hstack([img, cv2.GaussianBlur(img, ( 3, 3), 0)]),
  np.hstack([cv2.GaussianBlur(img, ( 5, 5), 0), cv2.GaussianBlur(img, ( 7, 7), 0)]),
  np.hstack([cv2.GaussianBlur(img, ( 9, 9), 0), cv2.GaussianBlur(img, (11, 11), 0)]),
])

plt.subplot(1,1,1)
plt.axis('off')
plt.imshow(suave)
plt.title('Imagem original e suavisadas pelo filtro Gaussiano', fontSize=24)
# Out:
# Text(0.5, 1.0, 'Imagem original e suavisadas pelo filtro Gaussiano')

# %% [markdown]
# ###Suavização pela mediana

# %%
img = cv2.imread('/content/gdrive/MyDrive/IMG_0074 (1).jpg')
img = img[::2,::2] # Diminui a imagem
suave = np.vstack([
  np.hstack([img, cv2.medianBlur(img, 3)]),
  np.hstack([cv2.medianBlur(img, 5), cv2.medianBlur(img, 7)]),
  np.hstack([cv2.medianBlur(img, 9), cv2.medianBlur(img, 11)]),
])

plt.subplot(1,1,1)
plt.axis('off')
plt.imshow(suave)
plt.title('Imagem original e suavisadas pela mediana', fontSize=24)
# Out:
# Text(0.5, 1.0, 'Imagem original e suavisadas pela mediana')

# %% [markdown]
# ###Suavização com filtro bilateral

# %%
img = cv2.imread('/content/gdrive/MyDrive/IMG_0074 (1).jpg')
img = img[::2,::2] # Diminui a imagem
suave = np.vstack([
  np.hstack([img, cv2.bilateralFilter(img, 3, 21, 21)]),
  np.hstack([cv2.bilateralFilter(img, 5, 35, 35), cv2.bilateralFilter(img, 7, 49, 49)]),
  np.hstack([cv2.bilateralFilter(img, 9, 63, 63), cv2.bilateralFilter(img, 11, 77, 77)])
])

plt.subplot(1,1,1)
plt.axis('off')
plt.imshow(suave)
plt.title('Imagem original e suavisadas com filtro bilateral', fontSize=24)
# Out:
# Text(0.5, 1.0, 'Imagem original e suavisadas com filtro bilateral')

# %% [markdown]
# ##Binarização com limiar

# %%
img = cv2.imread('/content/gdrive/MyDrive/IMG_0074 (1).jpg')
img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
suave = cv2.GaussianBlur(img, (7, 7), 0) # aplica blur
(T, bin) = cv2.threshold(suave, 160, 255, cv2.THRESH_BINARY)
(T, binI) = cv2.threshold(suave, 160, 255, cv2.THRESH_BINARY_INV)
resultado = np.vstack([ np.hstack([suave, bin]), np.hstack([binI, cv2.bitwise_and(img, img, mask = binI)]) ])

plt.subplot(1,1,1)
plt.axis('off')
plt.imshow(resultado)
plt.title('Binarização da imagem', fontSize=24)
# Out:
# Text(0.5, 1.0, 'Binarização da imagem')

# %% [markdown]
# ###Threshold adaptativo

# %%
img = cv2.imread('/content/gdrive/MyDrive/IMG_0074 (1).jpg')
img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY) # converte
suave = cv2.GaussianBlur(img, (7, 7), 0) # aplica blur
bin1 = cv2.adaptiveThreshold(suave, 255, cv2.ADAPTIVE_THRESH_MEAN_C, cv2.THRESH_BINARY_INV, 21, 5)
bin2 = cv2.adaptiveThreshold(suave, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C, cv2.THRESH_BINARY_INV, 21, 5)
resultado = np.vstack([ np.hstack([img, suave]), np.hstack([bin1, bin2]) ])

plt.subplot(1,1,1)
plt.axis('off')
plt.imshow(resultado)
plt.title('Binarização adaptativa da imagem', fontSize=24)
# Out:
# Text(0.5, 1.0, 'Binarização adaptativa da imagem')

# %% [markdown]
# ###Threshold com Otsu e Riddler-Calvard

# %%
# !pip install mahotas
import mahotas
img = cv2.imread('/content/gdrive/MyDrive/IMG_0074 (1).jpg')
img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY) # converte
suave = cv2.GaussianBlur(img, (7, 7), 0) # aplica blur
T = mahotas.thresholding.otsu(suave)
temp = img.copy()
temp[temp > T] = 255
temp[temp < 255] = 0
temp = cv2.bitwise_not(temp)
T = mahotas.thresholding.rc(suave)
temp2 = img.copy()
temp2[temp2 > T] = 255
temp2[temp2 < 255] = 0
temp2 = cv2.bitwise_not(temp2)
resultado = np.vstack([ np.hstack([img, suave]), np.hstack([temp, temp2]) ])

plt.subplot(1,1,1)
plt.axis('off')
plt.imshow(resultado)
plt.title('Binarização com método Otsu e Riddler-Calvard', fontSize=24)
# Out:
# ...
#      |████████████████████████████████| 5.7 MB 4.6 MB/s
# ...
# Text(0.5, 1.0, 'Binarização com método Otsu e Riddler-Calvard')

# %% [markdown]
# ##Segmentação e métodos de detecção de bordas

# %% [markdown]
# ###Sobel

# %%
img = cv2.imread('/content/gdrive/MyDrive/IMG_0074 (1).jpg')
img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
sobelX = cv2.Sobel(img, cv2.CV_64F, 1, 0)
sobelY = cv2.Sobel(img, cv2.CV_64F, 0, 1)
sobelX = np.uint8(np.absolute(sobelX))
sobelY = np.uint8(np.absolute(sobelY))
sobel = cv2.bitwise_or(sobelX, sobelY)
resultado = np.vstack([ np.hstack([img, sobelX]), np.hstack([sobelY, sobel]) ])

plt.subplot(1,1,1)
plt.axis('off')
plt.imshow(resultado)
plt.title('Sobel', fontSize=24)
# Out:
# Text(0.5, 1.0, 'Sobel')

# %% [markdown]
# ###Filtro Laplaciano

# %%
img = cv2.imread('/content/gdrive/MyDrive/IMG_0074 (1).jpg')
img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
lap = cv2.Laplacian(img, cv2.CV_64F)
lap = np.uint8(np.absolute(lap))
resultado = np.vstack([img, lap])

plt.subplot(1,1,1)
plt.axis('off')
plt.imshow(resultado)
plt.title('Filtro Laplaciano', fontSize=24)
# Out:
# Text(0.5, 1.0, 'Filtro Laplaciano')

# %% [markdown]
# ###Detector de bordas Canny

# %%
img = cv2.imread('/content/gdrive/MyDrive/IMG_0074 (1).jpg')
img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
suave = cv2.GaussianBlur(img, (7, 7), 0)
canny1 = cv2.Canny(suave, 20, 120)
canny2 = cv2.Canny(suave, 70, 200)
resultado = np.vstack([ np.hstack([img, suave ]), np.hstack([canny1, canny2]) ])

plt.subplot(1,1,1)
plt.axis('off')
plt.imshow(resultado)
plt.title('Detector de Bordas Canny', fontSize=24)
# Out:
# Text(0.5, 1.0, 'Detector de Bordas Canny')
